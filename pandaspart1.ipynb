# %% [markdown]
# <a href="https://colab.research.google.com/github/GunelXelilli/Pandaspart1/blob/main/pandaspart1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
masinlar=pd.Series(['BMW','TOYOTA','TESLA'])
masinlar
# Out:
# 0       BMW
# 1    TOYOTA
# 2     TESLA
# dtype: object

# %%
marka=['BMW','TOYOTA','TESLA']
masinlar=pd.Series(marka)
masinlar
# Out:
# 0       BMW
# 1    TOYOTA
# 2     TESLA
# dtype: object

# %%
masinlar.values
# Out:
# array(['BMW', 'TOYOTA', 'TESLA'], dtype=object)

# %%
masinlar.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
masinlar=pd.Series(marka,index=['a','b','c'])
masinlar
# Out:
# a       BMW
# b    TOYOTA
# c     TESLA
# dtype: object

# %%
masinlar.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
masinlar['a']
# Out:
# 'BMW'

# %%
bal={'Bayram':98,'Mehman':68,'Nazli':70}
a=pd.Series(bal)
a
# Out:
# Bayram    98
# Mehman    68
# Nazli     70
# dtype: int64

# %%
a['Mehman']
# Out:
# np.int64(68)

# %%
a>80
# Out:
# Bayram     True
# Mehman    False
# Nazli     False
# dtype: bool

# %%
a[a>80]
# Out:
# Bayram    98
# dtype: int64

# %%
a['Bayram']=80
a
# Out:
# Bayram    80
# Mehman    68
# Nazli     70
# dtype: int64

# %%
'Nazli' in a
# Out:
# True

# %%
a/10
# Out:
# Bayram    8.0
# Mehman    6.8
# Nazli     7.0
# dtype: float64

# %%
a//10
# Out:
# Bayram    8
# Mehman    6
# Nazli     7
# dtype: int64

# %%
a%2==0
# Out:
# Bayram    True
# Mehman    True
# Nazli     True
# dtype: bool

# %%
a.isnull().sum() # sum burada sayir true ve false 0+0=0 kimi
# Out:
# np.int64(0)

# %%
a.isnull() # null deyer olub -olmadigini yoxlayir
# Out:
# Bayram    False
# Mehman    False
# Nazli     False
# dtype: bool

# %%
a.isna() #N/A xetasi olub olmadigini yoxlayir
# Out:
# Bayram    False
# Mehman    False
# Nazli     False
# dtype: bool

# %% [markdown]
# #Dataframe

# %%
#ctrl+m (2x) basilaraq yaradildi

# %%
import pandas as pd

# %%
mar=pd.Series(['BMW','TESLA','TOYOTA'])
reng=pd.Series(['qara','ag','boz'])

# %%
masinlar=pd.DataFrame({'marka':mar,'Reng':reng})
masinlar
# Out:
#     marka  Reng
# 0     BMW  qara
# 1   TESLA    ag
# 2  TOYOTA   boz

# %%
data={'ad':['Bayram','Sevinc','Maryam','Teymur','Jasmine','Kamal','Ferman'],
      'cins':['k','q','q','k','q','k','k'],
      'bal':[67,98,34,78,78,78,90]
       }
df=pd.DataFrame(data)
df
# Out:
#         ad cins  bal
# 0   Bayram    k   67
# 1   Sevinc    q   98
# 2   Maryam    q   34
# 3   Teymur    k   78
# 4  Jasmine    q   78
# 5    Kamal    k   78
# 6   Ferman    k   90

# %%
df.head() #ilk 5 setir ama icinde 3 falan yazsam 3 unu gorece, df.head(3)
# Out:
#         ad cins  bal
# 0   Bayram    k   67
# 1   Sevinc    q   98
# 2   Maryam    q   34
# 3   Teymur    k   78
# 4  Jasmine    q   78

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['ad', 'cins', 'bal', 'status'], dtype='object')

# %%
df.tail() #son 5 setir
# Out:
#         ad cins  bal
# 2   Maryam    q   34
# 3   Teymur    k   78
# 4  Jasmine    q   78
# 5    Kamal    k   78
# 6   Ferman    k   90

# %%
df.sample() #random sekilde deyer getirir ve icine ne qeder (3) yazsam o qeder cixacaq
# Out:
#        ad cins  bal
# 1  Sevinc    q   98

# %%
df=pd.DataFrame(data,columns=('ad','cins','bal','yas'))
df
# Out:
#         ad cins  bal  yas
# 0   Bayram    k   67  NaN
# 1   Sevinc    q   98  NaN
# 2   Maryam    q   34  NaN
# 3   Teymur    k   78  NaN
# 4  Jasmine    q   78  NaN
# 5    Kamal    k   78  NaN
# 6   Ferman    k   90  NaN

# %%
df['status']='telebe'
df
# Out:
#         ad cins  bal  yas  status
# 0   Bayram    k   67  NaN  telebe
# 1   Sevinc    q   98  NaN  telebe
# 2   Maryam    q   34  NaN  telebe
# 3   Teymur    k   78  NaN  telebe
# 4  Jasmine    q   78  NaN  telebe
# 5    Kamal    k   78  NaN  telebe
# 6   Ferman    k   90  NaN  telebe

# %%
df['yas']=18
df
# Out:
#         ad cins  bal  yas  status
# 0   Bayram    k   67   18  telebe
# 1   Sevinc    q   98   18  telebe
# 2   Maryam    q   34   18  telebe
# 3   Teymur    k   78   18  telebe
# 4  Jasmine    q   78   18  telebe
# 5    Kamal    k   78   18  telebe
# 6   Ferman    k   90   18  telebe

# %%
df.isnull().sum()
# Out:
# ad        0
# cins      0
# bal       0
# yas       0
# status    0
# dtype: int64

# %%
df['cins']
# Out:
# 0    k
# 1    q
# 2    q
# 3    k
# 4    q
# 5    k
# 6    k
# Name: cins, dtype: object

# %%
df[['cins','yas']] # iki ve daha cox sutun getirmek isteyirikse onda [[ ]] ic-ice yazmaq lazimdir
# Out:
#   cins  yas
# 0    k   18
# 1    q   18
# 2    q   18
# 3    k   18
# 4    q   18
# 5    k   18
# 6    k   18

# %%
df.iloc[2] # index location
# Out:
# ad        Maryam
# cins           q
# bal           34
# yas           18
# status    telebe
# Name: 2, dtype: object

# %%
df.iloc[2,[2,3]] # 2-ci setir,(2,3)-sutun melumatlara
# Out:
# bal    34
# yas    18
# Name: 2, dtype: object

# %%
df.loc[2,['bal']] #loc sutun adlarinin hansi indeksde olduqlarini bilir
# Out:
# bal    34
# Name: 2, dtype: object

# %%
df['Imtkec']=df['bal']>50
df
# Out:
#         ad cins  bal  yas  status  Imtkec
# 0   Bayram    k   67   18  telebe    True
# 1   Sevinc    q   98   18  telebe    True
# 2   Maryam    q   34   18  telebe   False
# 3   Teymur    k   78   18  telebe    True
# 4  Jasmine    q   78   18  telebe    True
# 5    Kamal    k   78   18  telebe    True
# 6   Ferman    k   90   18  telebe    True

# %%
del df['Imtkec']
df
# Out:
#         ad cins  bal  yas  status
# 0   Bayram    k   67   18  telebe
# 1   Sevinc    q   98   18  telebe
# 2   Maryam    q   34   18  telebe
# 3   Teymur    k   78   18  telebe
# 4  Jasmine    q   78   18  telebe
# 5    Kamal    k   78   18  telebe
# 6   Ferman    k   90   18  telebe

# %%
df.T #transpose edir
# Out:
#              0       1       2       3        4       5       6
# ad      Bayram  Sevinc  Maryam  Teymur  Jasmine   Kamal  Ferman
# cins         k       q       q       k        q       k       k
# bal         67      98      34      78       78      78      90
# yas         18      18      18      18       18      18      18
# status  telebe  telebe  telebe  telebe   telebe  telebe  telebe

# %%
df[0:4]
# Out:
#        ad cins  bal  yas  status
# 0  Bayram    k   67   18  telebe
# 1  Sevinc    q   98   18  telebe
# 2  Maryam    q   34   18  telebe
# 3  Teymur    k   78   18  telebe

# %%
df=df.drop('yas',axis=1) #axis=1 sutun olaraq qebul edilir,axis=0 ise setir olaraq qebul edilir
df # birdefelik silmek ucun df=df.drop etmek lazimdir sadese df.drop yazsaq bir muddetlik gosterecek tam silmeyecek
# Out:
#         ad cins  bal  status
# 0   Bayram    k   67  telebe
# 1   Sevinc    q   98  telebe
# 2   Maryam    q   34  telebe
# 3   Teymur    k   78  telebe
# 4  Jasmine    q   78  telebe
# 5    Kamal    k   78  telebe
# 6   Ferman    k   90  telebe

# %%
df.sort_index(ascending=False)
# Out:
#        ad cins  bal  status
# 6  Ferman    k   90  telebe
# 5   Kamal    k   78  telebe
# 2  Maryam    q   34  telebe
# 1  Sevinc    q   98  telebe
# 0  Bayram    k   67  telebe

# %%
df.sort_index(axis=1) #sutun adlarini siralayir ve sensitivdir boyuk kicik heriflere qarsi
# Out:
#        ad  bal cins  status
# 0  Bayram   67    k  telebe
# 1  Sevinc   98    q  telebe
# 2  Maryam   34    q  telebe
# 5   Kamal   78    k  telebe
# 6  Ferman   90    k  telebe
